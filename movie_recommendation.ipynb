# %% [markdown]
# <a href="https://colab.research.google.com/github/satanismit/Recommendation_System/blob/main/movie_recommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
movie = '/content/drive/MyDrive/ml-1m/ml-1m/movies.dat'
users = '/content/drive/MyDrive/ml-1m/ml-1m/users.dat'
ratings = '/content/drive/MyDrive/ml-1m/ml-1m/ratings.dat'

# %%
with open(movie, 'r', encoding='latin-1') as file:
    for _ in range(5):
        print(file.readline())
# Out:
# 1::Toy Story (1995)::Animation|Children's|Comedy
#
# 2::Jumanji (1995)::Adventure|Children's|Fantasy
#
# 3::Grumpier Old Men (1995)::Comedy|Romance
#
# 4::Waiting to Exhale (1995)::Comedy|Drama
#
# 5::Father of the Bride Part II (1995)::Comedy

# %%
import pandas as pd

movies = pd.read_csv(movie, sep='::', engine='python', header=None, encoding='latin-1')
movies.head(100)
# Out:
#       0                                     1                             2
# 0     1                      Toy Story (1995)   Animation|Children's|Comedy
# 1     2                        Jumanji (1995)  Adventure|Children's|Fantasy
# 2     3               Grumpier Old Men (1995)                Comedy|Romance
# 3     4              Waiting to Exhale (1995)                  Comedy|Drama
# 4     5    Father of the Bride Part II (1995)                        Comedy
# ..  ...                                   ...                           ...
# 95   97               Hate (Haine, La) (1995)                         Drama
# 96   98                       Shopping (1994)               Action|Thriller
# 97   99  Heidi Fleiss: Hollywood Madam (1995)                   Documentary
# 98  100                      City Hall (1996)                Drama|Thriller
# 99  101                  Bottle Rocket (1996)                        Comedy
#
# [100 rows x 3 columns]

# %%
movies.columns = ['id', 'Movies', 'genres']

# %%
movies.head()
# Out:
#    id                              Movies                        genres
# 0   1                    Toy Story (1995)   Animation|Children's|Comedy
# 1   2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2   3             Grumpier Old Men (1995)                Comedy|Romance
# 3   4            Waiting to Exhale (1995)                  Comedy|Drama
# 4   5  Father of the Bride Part II (1995)                        Comedy

# %%
movies.shape
# Out:
# (3883, 3)

# %%
# i want to seperate movies name and year of relese and remove year from movies column
movies['year'] = movies['Movies'].str.extract(r'(\d{4})')

# %%
movies.head()
# Out:
#    id                              Movies                        genres  year
# 0   1                    Toy Story (1995)   Animation|Children's|Comedy  1995
# 1   2                      Jumanji (1995)  Adventure|Children's|Fantasy  1995
# 2   3             Grumpier Old Men (1995)                Comedy|Romance  1995
# 3   4            Waiting to Exhale (1995)                  Comedy|Drama  1995
# 4   5  Father of the Bride Part II (1995)                        Comedy  1995

# %%
movies.rename(columns={
    'id': 'movie_id' ,
    'Movies': 'movies' ,
    'genres': 'genres',
    'year': 'year'
                  }, inplace=True)

# %%
movies.head(3)
# Out:
#    movie_id                   movies                        genres  year
# 0         1         Toy Story (1995)   Animation|Children's|Comedy  1995
# 1         2           Jumanji (1995)  Adventure|Children's|Fantasy  1995
# 2         3  Grumpier Old Men (1995)                Comedy|Romance  1995

# %%
users = pd.read_csv(users, sep='::', engine='python', header=None, encoding='latin-1')

# %%
users.head(50)
# Out:
#      0  1   2   3      4
# 0    1  F   1  10  48067
# 1    2  M  56  16  70072
# 2    3  M  25  15  55117
# 3    4  M  45   7  02460
# 4    5  M  25  20  55455
# 5    6  F  50   9  55117
# 6    7  M  35   1  06810
# 7    8  M  25  12  11413
# 8    9  M  25  17  61614
# 9   10  F  35   1  95370
# 10  11  F  25   1  04093
# 11  12  M  25  12  32793
# 12  13  M  45   1  93304
# 13  14  M  35   0  60126
# 14  15  M  25   7  22903
# 15  16  F  35   0  20670
# 16  17  M  50   1  95350
# 17  18  F  18   3  95825
# 18  19  M   1  10  48073
# 19  20  M  25  14  55113
# 20  21  M  18  16  99353
# 21  22  M  18  15  53706
# 22  23  M  35   0  90049
# 23  24  F  25   7  10023
# 24  25  M  18   4  01609
# 25  26  M  25   7  23112
# 26  27  M  25  11  19130
# 27  28  F  25   1  14607
# 28  29  M  35   7  33407
# 29  30  F  35   7  19143
# 30  31  M  56   7  06840
# 31  32  F  25   0  19355
# 32  33  M  45   3  55421
# 33  34  F  18   0  02135
# 34  35  M  45   1  02482
# 35  36  M  25   3  94123
# ...

# %%
users.head()
# Out:
#    0  1   2   3      4
# 0  1  F   1  10  48067
# 1  2  M  56  16  70072
# 2  3  M  25  15  55117
# 3  4  M  45   7  02460
# 4  5  M  25  20  55455

# %%
users.columns = ['user_id', 'gender', 'age', 'occupation', 'zip']

# %%
users.drop(columns=['age','occupation' , 'zip'])
# Out:
#       user_id gender
# 0           1      F
# 1           2      M
# 2           3      M
# 3           4      M
# 4           5      M
# ...       ...    ...
# 6035     6036      F
# 6036     6037      F
# 6037     6038      F
# 6038     6039      F
# 6039     6040      M
#
# [6040 rows x 2 columns]

# %%
ratings = pd.read_csv(ratings, sep='::', engine='python', header=None, encoding='latin-1')

# %%
ratings.head()
# Out:
#    0     1  2          3
# 0  1  1193  5  978300760
# 1  1   661  3  978302109
# 2  1   914  3  978301968
# 3  1  3408  4  978300275
# 4  1  2355  5  978824291

# %%
ratings.columns = ['user_id', 'movie_id', 'rating', 'timestamp']

# %%
ratings.head()
# Out:
#    user_id  movie_id  rating  timestamp
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291

# %%
ratings.shape
# Out:
# (1000209, 4)

# %%
len(ratings['timestamp'].unique())
# Out:
# 458455

# %%
print(movies.shape)
print(users.shape)
print(ratings.shape)
# Out:
# (3883, 4)
# (6040, 5)
# (1000209, 4)

# %%
ratings['user_id'].value_counts()
# Out:
# user_id
# 4169    2314
# 1680    1850
# 4277    1743
# 1941    1595
# 1181    1521
#         ...
# 708       20
# 703       20
# 665       20
# 2160      20
# 4749      20
# Name: count, Length: 6040, dtype: int64

# %%
ratings['user_id'].unique().shape
# Out:
# (6040,)

# %%
x = ratings['user_id'].value_counts() > 200

# %%
x[x].shape
# Out:
# (1578,)

# %%
y = x[x].index

# %%
y
# Out:
# Index([4169, 1680, 4277, 1941, 1181,  889, 3618, 2063, 1150, 1015,
#        ...
#        3591, 2609, 3796, 3745, 4401, 4643, 3757, 2938,   15,  137],
#       dtype='int64', name='user_id', length=1578)

# %%
ratings.head()
# Out:
#    user_id  movie_id  rating  timestamp
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291

# %%
ratings = ratings[ratings['user_id'].isin(y)]

# %%
ratings.head()
# Out:
#      user_id  movie_id  rating  timestamp
# 799       10      2622       5  978228212
# 800       10       648       4  978224925
# 801       10      2628       3  978228408
# 802       10      3358       5  978226378
# 803       10      3359       3  978227125

# %%
ratings.shape
# Out:
# (654781, 4)

# %%
movies.head()
# Out:
#    movie_id                              movies                        genres  \
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy
#
#    year
# 0  1995
# 1  1995
# 2  1995
# 3  1995
# 4  1995

# %%
ratings_with_movies = ratings.merge(movies, on='movie_id')

# %%
ratings_with_movies.head()
# Out:
#    user_id  movie_id  rating  timestamp  \
# 0       10      2622       5  978228212
# 1       10       648       4  978224925
# 2       10      2628       3  978228408
# 3       10      3358       5  978226378
# 4       10      3359       3  978227125
#
#                                              movies  \
# 0                 Midsummer Night's Dream, A (1999)
# 1                        Mission: Impossible (1996)
# 2  Star Wars: Episode I - The Phantom Menace (1999)
# 3                        Defending Your Life (1991)
# 4                              Breaking Away (1979)
#
#                             genres  year
# 0                   Comedy|Fantasy  1999
# 1         Action|Adventure|Mystery  1996
# 2  Action|Adventure|Fantasy|Sci-Fi  1999
# 3                   Comedy|Romance  1991
# 4                            Drama  1979

# %%
ratings_with_movies.shape
# Out:
# (654781, 7)

# %%
 num_ratings = ratings_with_movies.groupby('movies')['rating'].count().reset_index()

# %%
num_ratings.head(25)
# Out:
#                                             movies  rating
# 0                           $1,000,000 Duck (1971)      33
# 1                             'Night Mother (1986)      52
# 2                        'Til There Was You (1997)      38
# 3                               'burbs, The (1989)     238
# 4                    ...And Justice for All (1979)     135
# 5                10 Things I Hate About You (1999)     364
# 6                            101 Dalmatians (1961)     369
# 7                            101 Dalmatians (1996)     234
# 8                              12 Angry Men (1957)     347
# 9                         13th Warrior, The (1999)     398
# 10                                      187 (1997)      39
# 11                     2 Days in the Valley (1996)     217
# 12                                 20 Dates (1998)      75
# 13             20,000 Leagues Under the Sea (1954)     357
# 14                           200 Cigarettes (1999)     142
# ...

# %%
num_ratings.rename(columns={'rating': 'num_of_ratings'}, inplace=True)

# %%
final_ratings=ratings_with_movies.merge(num_ratings, on='movies')

# %%
final_ratings.head()
# Out:
#    user_id  movie_id  rating  timestamp  \
# 0       10      2622       5  978228212
# 1       10       648       4  978224925
# 2       10      2628       3  978228408
# 3       10      3358       5  978226378
# 4       10      3359       3  978227125
#
#                                              movies  \
# 0                 Midsummer Night's Dream, A (1999)
# 1                        Mission: Impossible (1996)
# 2  Star Wars: Episode I - The Phantom Menace (1999)
# 3                        Defending Your Life (1991)
# 4                              Breaking Away (1979)
#
#                             genres  year  num_of_ratings
# 0                   Comedy|Fantasy  1999             235
# 1         Action|Adventure|Mystery  1996             898
# 2  Action|Adventure|Fantasy|Sci-Fi  1999            1035
# 3                   Comedy|Romance  1991             335
# 4                            Drama  1979             348

# %%
final_ratings.shape
# Out:
# (654781, 8)

# %%
final_ratings = final_ratings[final_ratings['num_of_ratings'] >= 50]

# %%
final_ratings.head()
# Out:
#    user_id  movie_id  rating  timestamp  \
# 0       10      2622       5  978228212
# 1       10       648       4  978224925
# 2       10      2628       3  978228408
# 3       10      3358       5  978226378
# 4       10      3359       3  978227125
#
#                                              movies  \
# 0                 Midsummer Night's Dream, A (1999)
# 1                        Mission: Impossible (1996)
# 2  Star Wars: Episode I - The Phantom Menace (1999)
# 3                        Defending Your Life (1991)
# 4                              Breaking Away (1979)
#
#                             genres  year  num_of_ratings
# 0                   Comedy|Fantasy  1999             235
# 1         Action|Adventure|Mystery  1996             898
# 2  Action|Adventure|Fantasy|Sci-Fi  1999            1035
# 3                   Comedy|Romance  1991             335
# 4                            Drama  1979             348

# %%
final_ratings.shape
# Out:
# (629981, 8)

# %%
final_ratings.duplicated().sum()
# Out:
# np.int64(0)

# %%
final_ratings.drop_duplicates(inplace=True)

# %%
final_ratings.duplicated().sum()
# Out:
# np.int64(0)

# %%
final_ratings.shape
# Out:
# (629981, 8)

# %%
movies_pivot = final_ratings.pivot_table(columns='user_id', index='movies', values='rating')

# %%
movies_pivot.head()
# Out:
# user_id                            10    15    17    18    19    22    23    \
# movies
# 'Night Mother (1986)                NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 'burbs, The (1989)                  4.0   NaN   NaN   NaN   NaN   4.0   NaN
# ...And Justice for All (1979)       NaN   NaN   NaN   NaN   NaN   NaN   2.0
# 10 Things I Hate About You (1999)   NaN   NaN   NaN   NaN   NaN   2.0   NaN
# 101 Dalmatians (1961)               NaN   NaN   NaN   4.0   4.0   NaN   NaN
#
# user_id                            26    33    36    ...  6002  6003  6007  \
# movies                                               ...
# 'Night Mother (1986)                NaN   NaN   NaN  ...   NaN   NaN   NaN
# 'burbs, The (1989)                  NaN   NaN   NaN  ...   NaN   NaN   NaN
# ...And Justice for All (1979)       NaN   NaN   NaN  ...   NaN   NaN   NaN
# 10 Things I Hate About You (1999)   NaN   NaN   NaN  ...   NaN   NaN   NaN
# ...

# %%
movies_pivot.shape
# Out:
# (2326, 1578)

# %%
movies_pivot.fillna(0, inplace=True)

# %%
from scipy.sparse import csr_matrix

movies_sparse = csr_matrix(movies_pivot)

# %%
movies_sparse
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 629981 stored elements and shape (2326, 1578)>

# %%
from sklearn.neighbors import NearestNeighbors

model = NearestNeighbors(algorithm='brute')

# %%
model.fit(movies_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
distances, suggestions = model.kneighbors(movies_pivot.iloc[237, :].values.reshape(1, -1), n_neighbors=6)

# %%
distances
# Out:
# array([[ 0.        , 40.06245125, 40.18706259, 40.26164428, 40.64480287,
#         40.68169121]])

# %%
suggestions
# Out:
# array([[ 237,  195,  684,  979, 1122,  803]])

# %%
for i in range(len(suggestions)):
    print(movies_pivot.index[suggestions[i]])
# Out:
# Index(['Big Hit, The (1998)', 'Bats (1999)', 'Fair Game (1995)',
#        'High School High (1996)', 'Jury Duty (1995)',
#        'Fright Night Part II (1989)'],
#       dtype='object', name='movies')

# %%
movies_name = movies_pivot.index

# %%
import os

# Create directory if it doesn't exist
os.makedirs('artifacts', exist_ok=True)

# %%
import pickle

pickle.dump(model, open('artifacts/model.pkl', 'wb'))
pickle.dump(movies_name, open('artifacts/movies_name.pkl', 'wb'))
pickle.dump(final_ratings, open('artifacts/final_ratings.pkl', 'wb'))
pickle.dump(movies_pivot, open('artifacts/movies_pivot.pkl', 'wb'))

# %%
from google.colab import files
# Zip the artifacts folder
# !zip -r artifacts.zip artifacts

# Download the zip file
files.download('artifacts.zip')
# Out:
# updating: artifacts/ (stored 0%)
# updating: artifacts/model.pkl (deflated 86%)
# updating: artifacts/final_ratings.pkl (deflated 82%)
# updating: artifacts/movies_name.pkl (deflated 59%)
# updating: artifacts/movies_pivot.pkl (deflated 96%)

# %%
import numpy as np
def recommend(movie_name):
    movie_id = np.where(movies_pivot.index == movie_name)[0][0]
    distances, suggestions = model.kneighbors(movies_pivot.iloc[movie_id, :].values.reshape(1, -1), n_neighbors=6)

    for i in range(len(suggestions)):
      movies = movies_pivot.index[suggestions[i]]
      for j in movies:
        print(j)

# %%
movie_name = 'Bats (1999)'
recommend(movie_name)
# Out:
# Bats (1999)
# Child's Play 3 (1992)
# King Kong Lives (1986)
# Free Willy 3: The Rescue (1997)
# Friday the 13th Part VIII: Jason Takes Manhattan (1989)
# Meatballs III (1987)
